# %%
print("hi")
# Out:
# hi

# %%
VIDEO_LINKS = {
    "University Lecture": [
        "https://www.youtube.com/watch?v=HtSuA80QTyo",
        "https://www.youtube.com/watch?v=shTBSGoYtK0",
    ],
    "Software Tutorial (Photoshop Basics)": [
        "https://www.youtube.com/watch?v=IyR_uYsRdPs",
        "https://www.youtube.com/watch?v=xTzvQkOll2U",
    ],
    "Whiteboard Explainer": [
        "https://www.youtube.com/watch?v=zDZFcDGpL4U",
        "https://www.youtube.com/watch?v=1nBwfZZvjKo",
    ],
    "Math Problem Solving": [
        "https://www.youtube.com/watch?v=WUvTyaaNkzM",
        "https://www.youtube.com/watch?v=AegzQ_dip8k",
    ],
    "Cooking Recipe": [
        "https://www.youtube.com/watch?v=roCX0AfBseQ",
        "https://www.youtube.com/watch?v=VhJFyyukAzA",
    ],
    "Science Experiment Demo": [
        "https://www.youtube.com/watch?v=Kou7ur5xt_4",
        "https://www.youtube.com/watch?v=ekUbBot8tDA",
    ],
    "DIY/Crafting Tutorial": [
        "https://www.youtube.com/watch?v=Ux1ECrNDZl4",
        "https://www.youtube.com/watch?v=LhZ2_Q9AVMA",
    ],
    "Tech Product Review": [
        "https://www.youtube.com/watch?v=XaqOejIaFgM",
        "https://www.youtube.com/watch?v=MRtg6A1f2Ko",
    ],
    "Video Game Review": [
        "https://www.youtube.com/watch?v=dIynuCeLOoc",
        "https://www.youtube.com/watch?v=BW_h1zD2luY",
    ],
    "Movie/TV Show Review": [
        "https://www.youtube.com/watch?v=gm2Ywo25eX8",
        "https://www.youtube.com/watch?v=H3jaIhSj23E",
    ],
    "Video Essay": [
        "https://www.youtube.com/watch?v=VYJtb2YXae8",
        "https://www.youtube.com/watch?v=FkPmiUFZyu8",
    ],
    "Financial News Report": [
        "https://www.youtube.com/watch?v=G8IAkeZ4icM",
        "https://www.youtube.com/watch?v=f39oHo6vFLg",
    ],
    "Podcast Interview": [
        "https://www.youtube.com/watch?v=FmlhA3dpxnc",
        "https://www.youtube.com/watch?v=idNM_AiGb40",
    ],
    "Daily Vlog": [
        "https://www.youtube.com/watch?v=igZ6PoZAszQ",
        "https://www.youtube.com/watch?v=Ygj9vBF_WUk",
    ],
    "Travel Vlog": [
        "https://www.youtube.com/watch?v=TAhynE00lB4",
        "https://www.youtube.com/watch?v=-Zp9urVQPqQ",
    ],
    "Comedy Sketch": [
        "https://www.youtube.com/watch?v=Dd7FixvoKBw",
        "https://www.youtube.com/watch?v=eToLDKheElg",
    ],
    "Unboxing Video": [
        "https://www.youtube.com/watch?v=7BOCJFBxiXQ",
        "https://www.youtube.com/watch?v=piYf4gDthjY",
    ],
    "Fitness/Workout Routine": [
        "https://www.youtube.com/watch?v=2Z9g-AZinUc",
        "https://www.youtube.com/watch?v=N3e8UXMdqOM",
    ],
    "Car Maintenance Tutorial": [
        "https://www.youtube.com/watch?v=O1hF25Cowv8",
        "https://www.youtube.com/watch?v=TnS53T3gcPg",
    ],
    "Musical Instrument Lesson": [
        "https://www.youtube.com/watch?v=HNSaXAe8tyg",
        "https://www.youtube.com/watch?v=lRJ_d3PqPIQ",
    ],
    "Digital Art/Painting Tutorial": [
        "https://www.youtube.com/watch?v=O40KGoCmpNA",
        "https://www.youtube.com/watch?v=QwtFYWczrXY",
    ],
    "Documentary": [
        "https://www.youtube.com/watch?v=abtpt1S6VsA",
        "https://www.youtube.com/watch?v=yQ6VOOd73MA",
    ],
    "Movie Trailer": [
        "https://www.youtube.com/watch?v=Way9Dexny3w",
        "https://www.youtube.com/watch?v=uYPbbksJxIg",
    ],
    "Live Concert Footage": [
        "https://www.youtube.com/watch?v=AEp08vVYreg",
        "https://www.youtube.com/watch?v=gDCLXTOvRBw",
    ],
    "Product Infomercial": [
        "https://www.youtube.com/watch?v=0xzN6FM5x_E",
        "https://www.youtube.com/watch?v=2PU8ZxQj7eE",
    ],
}

# %%
from langchain_qdrant import QdrantVectorStore
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from fastembed import ImageEmbedding, TextEmbedding

# %%
qdrant_client.get_collections().collections[0].name
# Out:
# 'Test_0.001'

# %%
[collection.name for collection in qdrant_client.get_collections().collections]
# Out:
# ['Test_0.001', 'Test_0.002']

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")

# %%
image_model = ImageEmbedding("Qdrant/clip-ViT-B-32-vision")
text_model = TextEmbedding(model_name="Qdrant/clip-ViT-B-32-text")
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# c:\Users\bored\Documents\YT_RAG\YT_RAG\.venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\bored\AppData\Local\Temp\fastembed_cache\models--Qdrant--clip-ViT-B-32-vision. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
text_model = TextEmbedding(model_name="Qdrant/clip-ViT-B-32-text")

# %%
text_model = TextEmbedding(model_name="Qdrant/clip-ViT-B-32-text")

# %%
from pathlib import Path

def list_images(dir_path: str):
    p = Path(dir_path)
    exts = ("*.jpg", "*.jpeg", "*.png", "*.webp")
    files = [f.resolve() for pattern in exts for f in p.glob(pattern)]
    return sorted(files)  

imgs = list_images("video_frames_output")
# If you want strings:
img_paths = [str(p) for p in imgs]
# If you want file:// URIs:
img_uris = [p.as_uri() for p in imgs]

# %%
imgs=list_images("./video_frames_output")

# %%
img_uris=[p.as_uri() for p in imgs]

# %%
img_uris
# Out:
# ['file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_0_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_10_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_20_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_30_sec.jpg']

# %%
def convert_to_base64(imgs):
  base64_strings = []
  for path in imgs:                       # <-- iterate Paths
      with path.open("rb") as f:
          b64 = base64.b64encode(f.read()).decode("utf-8")  # bytes -> str
      base64_strings.append(b64)
  return base64_strings

# %%
from pathlib import Path
import base64

def list_images(dir_path: str):
    p = Path(dir_path)
    exts = ("*.jpg", "*.jpeg", "*.png", "*.webp")
    files = [f.resolve() for pattern in exts for f in p.glob(pattern)]
    return sorted(files)

# 1) Get Path objects (NOT URIs)
imgs = list_images("./video_frames_output")

# If you still need URIs for something else:
img_uris = [p.as_uri() for p in imgs]   # don't use these with open()

# %%
imgs
# Out:
# [WindowsPath('C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_0_sec.jpg'),
#  WindowsPath('C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_10_sec.jpg'),
#  WindowsPath('C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_20_sec.jpg'),
#  WindowsPath('C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_30_sec.jpg')]

# %%
img_uris
# Out:
# ['file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_0_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_10_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_20_sec.jpg',
#  'file:///C:/Users/bored/Documents/YT_RAG/YT_RAG/notebooks/video_frames_output/frame_at_30_sec.jpg']

# %%
  frame_collection_name = "Test_0.002"
  qdrant_client.create_collection(
      collection_name=frame_collection_name,
      vectors_config=VectorParams(size=512, distance=Distance.COSINE)
  )
# Out:
# True

# %%
def make_embeddings(folder_path):
  imgs=list_images(folder_path)
  embeddings = list(image_model.embed(imgs))
  points = [
    PointStruct(id=idx,
                vector=embedding,
                payload={"path": imgs[idx],"vid_id":folder_path})
    for idx, embedding in enumerate(embeddings)
  ]

  qdrant_client.upsert(collection_name=frame_collection_name, points=points)

# %%
embeddings = list(image_model.embed(imgs))

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, VectorParams, Distance

frame_collection_name = "Test_0.001"
qdrant_client.create_collection(
    collection_name=frame_collection_name,
    vectors_config=VectorParams(size=512, distance=Distance.COSINE)
)
# Out:
# True

# %%
points = [
    PointStruct(id=idx,
                vector=embedding,
                payload={"path": imgs[idx]})
    for idx, embedding in enumerate(embeddings)
]

qdrant_client.upsert(collection_name=frame_collection_name, points=points)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
list(text_model.embed(["hello"]))
# Out:
# [array([ 2.20640097e-02,  2.31804413e-04, -6.08811807e-03,  2.26486679e-02,
#         -1.21631911e-02, -1.67861059e-02,  5.63766249e-03, -1.25407338e-01,
#         -6.44283369e-03,  4.05207218e-04, -6.97171455e-03, -1.80460121e-02,
#         -1.23587288e-02, -3.91786080e-03,  1.46590183e-02, -8.15012213e-03,
#          4.07049544e-02,  2.66235368e-03, -8.77924170e-03,  1.05392806e-04,
#          2.77000908e-02, -2.16296017e-02,  7.68737914e-03, -1.93079782e-03,
#         -2.21371278e-02, -2.33300887e-02, -9.16159432e-03,  1.10397292e-02,
#         -2.62168329e-03,  1.18536530e-02, -7.87180848e-03, -1.67949665e-02,
#         -3.10376310e-03, -1.50790391e-02,  5.45979477e-03, -5.23473974e-03,
#          4.35018912e-03,  6.52426097e-04,  2.28134915e-03,  6.33453717e-03,
#         -2.43185344e-03, -2.22846270e-02, -6.19847141e-03, -3.08117899e-03,
#          1.05321361e-02,  2.93309223e-02,  5.72931999e-03, -1.00385891e-02,
# ...

# %%
list(text_model.embed(["hello"]))[0]
# Out:
# array([ 2.20640097e-02,  2.31804413e-04, -6.08811807e-03,  2.26486679e-02,
#        -1.21631911e-02, -1.67861059e-02,  5.63766249e-03, -1.25407338e-01,
#        -6.44283369e-03,  4.05207218e-04, -6.97171455e-03, -1.80460121e-02,
#        -1.23587288e-02, -3.91786080e-03,  1.46590183e-02, -8.15012213e-03,
#         4.07049544e-02,  2.66235368e-03, -8.77924170e-03,  1.05392806e-04,
#         2.77000908e-02, -2.16296017e-02,  7.68737914e-03, -1.93079782e-03,
#        -2.21371278e-02, -2.33300887e-02, -9.16159432e-03,  1.10397292e-02,
#        -2.62168329e-03,  1.18536530e-02, -7.87180848e-03, -1.67949665e-02,
#        -3.10376310e-03, -1.50790391e-02,  5.45979477e-03, -5.23473974e-03,
#         4.35018912e-03,  6.52426097e-04,  2.28134915e-03,  6.33453717e-03,
#        -2.43185344e-03, -2.22846270e-02, -6.19847141e-03, -3.08117899e-03,
#         1.05321361e-02,  2.93309223e-02,  5.72931999e-03, -1.00385891e-02,
# ...

# %%
query_embedding = list(text_model.embed([" welcome to the wonderland"]))[0]

# %%
results = qdrant_client.search(
    collection_name=frame_collection_name,
    query_vector=query_embedding,
    limit=2
)
# Out:
# C:\Users\bored\AppData\Local\Temp\ipykernel_19804\510528764.py:1: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   results = qdrant_client.search(

# %%
frames_metadata = []

# %%
for frame in results:
    frames_metadata.append(
        {"score":frame.score,
          "id":frame.id,
          "image_path":frame.payload['path']
          }
    )

# %%
frames_metadata
# Out:
# [{'score': 0.1604896,
#   'id': 2,
#   'image_path': 'C:\\Users\\bored\\Documents\\YT_RAG\\YT_RAG\\notebooks\\video_frames_output\\frame_at_20_sec.jpg'},
#  {'score': 0.15738566,
#   'id': 3,
#   'image_path': 'C:\\Users\\bored\\Documents\\YT_RAG\\YT_RAG\\notebooks\\video_frames_output\\frame_at_30_sec.jpg'}]

# %%
frames_metadata[0]['image_path']
# Out:
# 'C:\\Users\\bored\\Documents\\YT_RAG\\YT_RAG\\notebooks\\video_frames_output\\frame_at_20_sec.jpg'

# %%
from pathlib import Path
from PIL import Image
from IPython.display import display

for item in frames_metadata:
    p = Path(item["image_path"])
    img = Image.open(p)
    display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360>

# %%
[item for item in VIDEO_LINKS]
# Out:
# ['University Lecture',
#  'Software Tutorial (Photoshop Basics)',
#  'Whiteboard Explainer',
#  'Math Problem Solving',
#  'Cooking Recipe',
#  'Science Experiment Demo',
#  'DIY/Crafting Tutorial',
#  'Tech Product Review',
#  'Video Game Review',
#  'Movie/TV Show Review',
#  'Video Essay',
#  'Financial News Report',
#  'Podcast Interview',
#  'Daily Vlog',
#  'Travel Vlog',
#  'Comedy Sketch',
#  'Unboxing Video',
#  'Fitness/Workout Routine',
#  'Car Maintenance Tutorial',
#  'Musical Instrument Lesson',
#  'Digital Art/Painting Tutorial',
#  'Documentary',
#  'Movie Trailer',
#  'Live Concert Footage',
#  'Product Infomercial']

# %%
import re

# %%
link=VIDEO_LINKS['Car Maintenance Tutorial'][0]

# %%
# Handles: youtube.com/watch?v=ID, youtu.be/ID, /embed/ID, /shorts/ID
YT_ID_RE = re.compile(r'(?:v=|youtu\.be/|embed/|shorts/)([A-Za-z0-9_-]{11})')

def get_yt_id(url: str) -> str | None:
    m = YT_ID_RE.search(url)
    return m.group(1) if m else None

# Example: one link
link = VIDEO_LINKS['Car Maintenance Tutorial'][0]
print(get_yt_id(link))  # -> O1hF25Cowv8

# Example: build a dict of IDs for all categories
VIDEO_IDS = {
    cat: [get_yt_id(u) for u in urls]
    for cat, urls in VIDEO_LINKS.items()
}
# Out:
# O1hF25Cowv8

# %%
VIDEO_IDS
# Out:
# {'University Lecture': ['HtSuA80QTyo', 'shTBSGoYtK0'],
#  'Software Tutorial (Photoshop Basics)': ['IyR_uYsRdPs', 'xTzvQkOll2U'],
#  'Whiteboard Explainer': ['zDZFcDGpL4U', '1nBwfZZvjKo'],
#  'Math Problem Solving': ['WUvTyaaNkzM', 'AegzQ_dip8k'],
#  'Cooking Recipe': ['roCX0AfBseQ', 'VhJFyyukAzA'],
#  'Science Experiment Demo': ['Kou7ur5xt_4', 'ekUbBot8tDA'],
#  'DIY/Crafting Tutorial': ['Ux1ECrNDZl4', 'LhZ2_Q9AVMA'],
#  'Tech Product Review': ['XaqOejIaFgM', 'MRtg6A1f2Ko'],
#  'Video Game Review': ['dIynuCeLOoc', 'BW_h1zD2luY'],
#  'Movie/TV Show Review': ['gm2Ywo25eX8', 'H3jaIhSj23E'],
#  'Video Essay': ['VYJtb2YXae8', 'FkPmiUFZyu8'],
#  'Financial News Report': ['G8IAkeZ4icM', 'f39oHo6vFLg'],
#  'Podcast Interview': ['FmlhA3dpxnc', 'idNM_AiGb40'],
#  'Daily Vlog': ['igZ6PoZAszQ', 'Ygj9vBF_WUk'],
#  'Travel Vlog': ['TAhynE00lB4', '-Zp9urVQPqQ'],
#  'Comedy Sketch': ['Dd7FixvoKBw', 'eToLDKheElg'],
#  'Unboxing Video': ['7BOCJFBxiXQ', 'piYf4gDthjY'],
# ...

# %%
import os
import subprocess
import yt_dlp

# %%
def get_video_info(youtube_url: str) -> dict:
    """
    Takes a YouTube URL and returns a dictionary containing the direct
    video stream URL and the video's duration in seconds.
    """
    ydl_opts = {'format': 'best[ext=mp4]'}
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(youtube_url, download=False)
        stream_url = info['url']
        duration = int(info['duration'])
        print(f"✅ Successfully found stream URL for a video of {duration} seconds.")
        return {'stream_url': stream_url, 'duration': duration}

# %%
def extract_frames_fast(stream_url: str):
    """
    Uses a single, efficient FFmpeg command to extract frames every 10 seconds.
    
    Args:
        stream_url: The direct video stream URL.
    """
    output_dir = "video_frames_output_fast"
    os.makedirs(output_dir, exist_ok=True)
    print(f"Directory '{output_dir}' created. Starting FAST frame extraction...")

    command = [
        'ffmpeg',
        '-i', stream_url,                     # Input from the direct stream URL
        '-vf', 'fps=1/10',                    # The filter to apply: 1 frame every 10 seconds
        f'{output_dir}/frame_%04d.jpg'         # The output file pattern
    ]

    try:
        subprocess.run(command, check=True, capture_output=True, text=True)
        print("\n🎉 All frames extracted successfully!")
    except subprocess.CalledProcessError as e:
        print("❌ FFmpeg command failed.")
        print(f"Error: {e.stderr}")

if __name__ == "__main__":
    my_youtube_url = "https://www.youtube.com/watch?v=t9mRf2S5vDI" # Example video

    video_info = get_video_info(my_youtube_url)

    if video_info:
        extract_frames_fast(stream_url=video_info['stream_url'])

# %%
import yt_dlp
import time


VIDEO_QUALITIES_TO_TEST = {
    "480p": "bestvideo[height<=480]+bestaudio/best",
    "720p": "bestvideo[height<=720]+bestaudio/best",
}

def get_video_info(youtube_url: str, format_str: str) -> dict:
    """
    Takes a YouTube URL and a format string, then returns a dictionary 
    containing the direct video stream URL and its duration in seconds.
    """
    ydl_opts = {
        'format': format_str,
        'quiet': True, # Suppress console output from yt-dlp
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(youtube_url, download=False)
        return {
            'stream_url': info.get('url'),
            'duration': int(info.get('duration', 0))
        }

# %%
def extract_frames_fast(stream_url: str,sf1f:str,vid:str):
    """
    Uses a single, efficient FFmpeg command to extract frames every 10 seconds.
    
    Args:
        stream_url: The direct video stream URL.
    """
    output_dir = vid
    os.makedirs(output_dir, exist_ok=True)
    print(f"Directory '{output_dir}' created. Starting FAST frame extraction...")

    command = [
        'ffmpeg',
        '-i', stream_url,                     # Input from the direct stream URL
        '-vf', 'fps=1/60',                    # The filter to apply: 1 frame every 10 seconds
        f'{output_dir}/frame_%04d.jpg'         # The output file pattern
    ]

    try:
        subprocess.run(command, check=True, capture_output=True, text=True)
    except subprocess.CalledProcessError as e:
        print(f"Error: {e.stderr}")

# %%
if __name__ == "__main__":
    my_youtube_url = "https://www.youtube.com/watch?v=t9mRf2S5vDI" # Example video

    video_info = get_video_info(my_youtube_url)
    print(video_info['stream_url'])
    vid_id=get_yt_id(my_youtube_url)


    if video_info:
        extract_frames_fast(stream_url=video_info['stream_url'],sf1f=20,vid=vid_id)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=t9mRf2S5vDI
# [youtube] t9mRf2S5vDI: Downloading webpage
# [youtube] t9mRf2S5vDI: Downloading tv client config
# [youtube] t9mRf2S5vDI: Downloading tv player API JSON
# [youtube] t9mRf2S5vDI: Downloading tv simply player API JSON
# ✅ Successfully found stream URL for a video of 1776 seconds.
# ...

# %%
      vid_info=get_video_info(vid,quality)

# %%
extract_frames_fast(stream_url=)

# %%
for format in VIDEO_QUALITIES_TO_TEST:
  quality=VIDEO_QUALITIES_TO_TEST[format]
  print(quality)
# Out:
# bestvideo[height<=480]+bestaudio/best
# bestvideo[height<=720]+bestaudio/best

# %%
frames_metadata = []

# %%
for item in VIDEO_LINKS:
  print("Going into the first loop")
  for i in range(2):
    print("looking for each item")
    vid=VIDEO_LINKS[item][1]
    vid_id=get_yt_id(vid)
    for format in VIDEO_QUALITIES_TO_TEST:
      print("tesing the video quality")
      quality=VIDEO_QUALITIES_TO_TEST[format]
      vid_info=get_video_info(vid,quality)
      for i in [20,30]:
        print("testing the frame rate")
        extract_frames_fast(stream_url=vid_info['stream_url'],sf1f=i,vid=vid_id)
        make_embeddings(vid_id)
        print("done making embeddings")
        query_embedding = list(text_model.embed([""]))[0]
        results = qdrant_client.search(
            collection_name=frame_collection_name,
            query_vector=query_embedding,
            limit=2
        )
        for frame in results:
          frames_metadata.append(
              {"score":frame.score,
                "id":frame.id,
                "image_path":frame.payload['path']
                }
          )
          break
        break
      break
    break
  break
# Out:
# Going into the first loop
# looking for each item
# tesing the video quality
# testing the frame rate
# Directory 'shTBSGoYtK0' created. Starting FAST frame extraction...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 13
#      11 for i in [20,30]:
#      12   print("testing the frame rate")
# ---> 13   extract_frames_fast(stream_url=vid_info['stream_url'],sf1f=i,vid=vid_id)
#      14   make_embeddings(vid_id)
#      15   print("done making embeddings")
#
# Cell In[66], line 20, in extract_frames_fast(stream_url, sf1f, vid)
#      12 command = [
#      13     'ffmpeg',
#      14     '-i', stream_url,                     # Input from the direct stream URL
#      15     '-vf', 'fps=1/{x}'.format(x=sf1f),                    # The filter to apply: 1 frame every 10 seconds
#      16     f'{output_dir}/frame_%04d.jpg'         # The output file pattern
# ...

# %%
for item in VIDEO_LINKS:
    # ... (your existing code) ...
    vid = VIDEO_LINKS[item][1]
    vid_id = get_video_info)
    print(vid_id)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       1 for item in VIDEO_LINKS:
#       2     # ... (your existing code) ...
#       3     vid = VIDEO_LINKS[item][1]
# ----> 4     vid_id = get_video_info(vid)
#       5     print(vid_id)
#       6     break
#
# TypeError: get_video_info() missing 1 required positional argument: 'format_str'

# %%
vid
# Out:
# 'https://www.youtube.com/watch?v=shTBSGoYtK0'

# %%
    
    for format in VIDEO_QUALITIES_TO_TEST:
        print("tesing the video quality")
        quality = VIDEO_QUALITIES_TO_TEST[format]
        vid_info = get_video_info(vid, quality)

        # --- THIS IS THE FIX ---
        # Check if the stream_url is valid before trying to use it
        if vid_info and vid_info.get('stream_url'):
            for i in [20, 30]:
                print("testing the frame rate")
                # Corrected parameter name from sf1f to interval
                extract_frames_fast(stream_url=vid_info['stream_url'], interval=i, vid_id=vid_id)

            make_embeddings(vid_id)
            print("done making embeddings")
            
            # ... (rest of your code for this loop) ...

        else:
            # Handle the case where the stream URL could not be found
            print(f"❌ Could not get a valid stream URL for video {vid_id} with quality '{format}'. Skipping.")

         # your break statements...
    break
break
# Out:
# tesing the video quality
# ❌ Could not get a valid stream URL for video shTBSGoYtK0 with quality '480p'. Skipping.
# tesing the video quality
# ❌ Could not get a valid stream URL for video shTBSGoYtK0 with quality '720p'. Skipping.
#   Cell In[80], line 24
#     break
#     ^
# SyntaxError: 'break' outside loop
